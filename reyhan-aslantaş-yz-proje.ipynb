# %%
print("merhaba bgt211 yapay zeka sınıfı")
# Out:
# merhaba bgt211 yapay zeka sınıfı

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/BGT211-YZ-Proje(Reyhan Aslantaş)')
# !pwd
# Out:
# /content/drive/MyDrive/BGT211-YZ-Proje(Reyhan Aslantaş)

# %%
import cv2
import sys

print("python sürüm bilgisi: ", sys.version)
print("opencv sürüm bilgisi: ", cv2.__version__)
# Out:
# python sürüm bilgisi:  3.10.12 (main, Jun 11 2023, 05:26:28) [GCC 11.4.0]
# opencv sürüm bilgisi:  4.8.0

# %%
import numpy as np

# %%
from google.colab.patches import cv2_imshow
image =cv2.imread('opencv-renkler.png')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=437x394>

# %%
lower_red=np.array([0, 0, 100])#alt limi satırı
upper_red=np.array([100, 100, 255])#üst limit satırı

# %%
mask =cv2.inRange(image, lower_red, upper_red)

# %%
result=cv2.bitwise_and(image, image, mask=mask)

# %%
cv2_imshow(result)
# Out:
# <PIL.Image.Image image mode=RGB size=437x394>

# %%
lower_green=np.array([100, 0, 100])#alt limi satırı
upper_green=np.array([255, 100, 255])

# %%
mask1=cv2.inRange(image, lower_green, upper_green)

# %%
result1=cv2.bitwise_and(image, image, mask=mask1)

# %%
cv2_imshow(result1)
# Out:
# <PIL.Image.Image image mode=RGB size=437x394>

# %%
from google.colab.patches import cv2_imshow
image =cv2.imread('indir.jpg')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=121x121>

# %%
lower_red=np.array([0,0,0])#alt limi satırı
upper_red=np.array([255, 255,0])#üst limit satırı

# %%
mask1=cv2.inRange(image, lower_green, upper_green)

# %%
result1=cv2.bitwise_and(image, image, mask=mask1)

# %%
cv2_imshow(result1)
# Out:
# <PIL.Image.Image image mode=RGB size=121x121>

# %%
image_rgb=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
pixels= image_rgb.reshape((-1,3))

# %%
unique_colors=set()

# %%
for pixel in pixels:
  unique_colors.add(tuple(pixel))

# %%
num_unique_colors=len(unique_colors)

# %%
print("resimdeki renk sayısı:", num_unique_colors)
# Out:
# resimdeki renk sayısı: 8673

# %% [markdown]
# cv2->opencv kütüphane dosyası
# sys->sys python sürüm kütüphanesi
